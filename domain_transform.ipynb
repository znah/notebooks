# %%
# %matplotlib inline
# %load_ext cythonmagic
from IPython.html.widgets import interact
import numpy as np
import cv2
from nbutils import showarray    
import pylab as pl

# %%
img = np.float32(cv2.imread('data/statue.png'))

# %%
# %%cython
# # cython:boundscheck=False
# # cython:wraparound=False
# import numpy as np
#
#
# def lineRF(float[:,:,:] dst, float[:,:] dt, float a):
#     cdef int i, j
#     cdef float s
#     cdef int h = dst.shape[0], w = dst.shape[1], cn = dst.shape[2]
#     for i in xrange(h):
#         for j in xrange(1, w):
#             s = a**dt[i,j-1]
#             for c in xrange(cn):
#                 dst[i,j,c] += s*(dst[i,j-1,c]-dst[i,j,c])
#
#
# def lineNC(float[:,:,:] src, float[:,:] ct, float r):
#     cdef int w = src.shape[1], cn = src.shape[2]
#     np_dst = np.zeros_like(src)
#     cdef float[:,:,:] dst = np_dst
#     cdef float t = 0.0
#     cdef int left, right
#     cdef float v[32]
#     for i in xrange(src.shape[0]):
#         for c in xrange(cn):
#             v[c] = 0.0
#         left, right = 0, 0
#         for j in xrange(w):
#             t = ct[i,j]
#             while ct[i,left] < t-r:
#                 for c in xrange(cn):
#                     v[c] -= src[i,left,c]
#                 left += 1
#             while right < w and ct[i,right] < t+r:
#                 for c in xrange(cn):
#                     v[c] += src[i,right,c]
#                 right += 1
#             for c in xrange(cn):
#                 dst[i,j,c] = v[c] / (right-left)
#     return np_dst

# %%
def DTfilter(I, sigma_s, sigma_r, G=None, iter_n=3, method='RF'):
    I = I.astype(np.float32)
    if G is None:
        G = I
    G = np.float32(G)

    def tr(a):
        return np.swapaxes(a, 0, 1)
    
    dIdx = np.abs(np.diff(G, axis=1)).sum(-1)
    dIdy = np.abs(np.diff(G, axis=0)).sum(-1)
    dHdx = (1 + sigma_s/sigma_r * dIdx)
    dVdy = (1 + sigma_s/sigma_r * dIdy)
    dVdyT = tr(dVdy).copy()
    
    if method != 'RF':
        ctH = np.zeros_like(dHdx)
        ctVT = np.zeros_like(dVdyT)
        ctH[:,1:] = dHdx[:,:-1].cumsum(1)
        ctVT[:,1:] = dVdyT[:,:-1].cumsum(1)
    
    for i in xrange(iter_n):
        sigma_H_i = sigma_s * np.sqrt(3) * 2**(iter_n - (i + 1)) / np.sqrt(4**iter_n - 1)
        
        if method == 'RF':
            a = np.exp(-np.sqrt(2) / sigma_H_i)
            lineRF(I, dHdx, a)
            lineRF(I[:,::-1], dHdx[:,::-1], a)
            lineRF(tr(I), dVdyT, a)
            lineRF(tr(I)[:,::-1], dVdyT[:,::-1], a)
        elif method == 'NC':
            r = np.sqrt(3)*sigma_H_i
            I = lineNC(I, ctH, r)
            I = tr(lineNC(tr(I), ctVT, r))
        else:
            assert False, 'unknown filtering method "%s"' % method
    return I

# %%
def show_filter(sigma_s=10, sigma_r=300.0, iter_n=3):
    resRF = DTfilter(img, sigma_s, sigma_r, iter_n=iter_n, method='RF')
    resNC = DTfilter(img, sigma_s, sigma_r, iter_n=iter_n, method='NC')
    showarray(np.hstack([resNC, resRF]))
    print "left - NC, right - RF"
interact(show_filter, sigma_s=(1,50), sigma_r=(1.0,1000.0), iter_n=(1,5))
# Out:
# left - NC, right - RF
